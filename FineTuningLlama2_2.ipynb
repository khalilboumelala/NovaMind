# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install peft

# %%
import pandas as pd
from datasets import Dataset

# %%
from transformers import Trainer, TrainingArguments, LlamaForCausalLM, LlamaTokenizer
from datasets import load_dataset

# %%
# Charger votre fichier Excel avec pandas
df = pd.read_excel('/content/base_finale_cleaned.xlsx')

# Afficher les premières lignes pour vérifier
df.head()
# Out:
#   Plateforme                     Brand Name  \
# 0  instagram  Magasins aziza - مغازات عزيزة
# 1  instagram  Magasins aziza - مغازات عزيزة
# 2  instagram  Magasins aziza - مغازات عزيزة
# 3  instagram  Magasins aziza - مغازات عزيزة
# 4  instagram  Magasins aziza - مغازات عزيزة
#
#                                           Link Brand              Type  \
# 0  https://www.instagram.com/magasins_aziza_offic...  Commerce général
# 1  https://www.instagram.com/magasins_aziza_offic...  Commerce général
# 2  https://www.instagram.com/magasins_aziza_offic...  Commerce général
# 3  https://www.instagram.com/magasins_aziza_offic...  Commerce général
# 4  https://www.instagram.com/magasins_aziza_offic...  Commerce général
#
#                                Product Link   Format  \
# 0  https://www.instagram.com/p/DGAdbmgoGPq/  sidecar
# 1  https://www.instagram.com/p/DGC7WyoJcSQ/    image
# 2  https://www.instagram.com/p/DGDrZztMkU7/    image
# ...

# %%
# Convertir le DataFrame en Dataset Hugging Face
dataset = Dataset.from_pandas(df)

# Vérifiez la structure du dataset
dataset
# Out:
# Dataset({
#     features: ['Plateforme', 'Brand Name', 'Link Brand', 'Type', 'Product Link', 'Format', 'Description', 'likesCount', 'Review'],
#     num_rows: 10259
# })

# %%
from huggingface_hub import login

login(token="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")  # Replace with your actual token

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from huggingface_hub import login
import torch

# ========== 1. AUTHENTICATION ==========
# No token needed for Llama-2 7B (only for 13B+ models)
# login(token="hf_your_token")  # Uncomment if using 13B

# ========== 2. MODEL SELECTION ==========
MODEL_NAME = "meta-llama/Llama-2-7b-chat-hf"  # 7B version doesn't require special access

# ========== 3. MEMORY CONFIGURATION ==========
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

# ========== 4. SAFE MODEL LOADING ==========
try:
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=quant_config,
        device_map="auto",
        torch_dtype=torch.float16
    )
    print(f"Successfully loaded {MODEL_NAME}")
except Exception as e:
    print(f"Error loading {MODEL_NAME}: {e}")
    print("Falling back to OpenLlama...")
    model = AutoModelForCausalLM.from_pretrained(
        "openlm-research/open_llama_7b",
        device_map="auto",
        load_in_4bit=True
    )

# ========== 5. TOKENIZER SETUP ==========
tokenizer = AutoTokenizer.from_pretrained(
    model.config._name_or_path,
    padding_side="left"
)
tokenizer.pad_token = tokenizer.eos_token or "[PAD]"

# ========== 6. VERIFICATION ==========
print("\n" + "="*50)
print(f"Model: {model.config._name_or_path}")
print(f"Device map: {model.hf_device_map}")
print("="*50 + "\n")

# Test inference
prompt = "Describe this product: Premium skincare serum with vitamin C"
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
outputs = model.generate(**inputs, max_new_tokens=100)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
# Créer un split train/validation (90% / 10%)
dataset = dataset.train_test_split(test_size=0.1, seed=42)
train_dataset = dataset["train"]
eval_dataset = dataset["test"]

# %%
# Check your dataset structure
print(train_dataset.features)
print(train_dataset[0])  # View first example

# Adjust your tokenize_function to match your actual columns
def tokenize_function(example):
    # Use the actual column names from your dataset
    text = f"### Instruction:\n{example['Description']}\n\n### Response:\n{example['Review']}"
    return tokenizer(text, truncation=True, padding="max_length", max_length=512)
# Out:
# {'Plateforme': Value(dtype='string', id=None), 'Brand Name': Value(dtype='string', id=None), 'Link Brand': Value(dtype='string', id=None), 'Type': Value(dtype='string', id=None), 'Product Link': Value(dtype='string', id=None), 'Format': Value(dtype='string', id=None), 'Description': Value(dtype='string', id=None), 'likesCount': Value(dtype='float64', id=None), 'Review': Value(dtype='string', id=None)}
# {'Plateforme': 'facebook', 'Brand Name': 'Mielboumiza -عسل بوميزة', 'Link Brand': 'https://www.facebook.com/Mielboumiza', 'Type': 'Miel', 'Product Link': 'https://www.facebook.com/reel/789993856262409/', 'Format': 'video', 'Description': 'شكراً على تقييم منتجاتنا ✔️', 'likesCount': 514.0, 'Review': None}

# %%
import pandas as pd
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    BitsAndBytesConfig
)
from peft import LoraConfig, get_peft_model

# 1. Load and prepare data
df = pd.read_excel("/content/base_finale_cleaned.xlsx")
df = df.rename(columns={"Description": "response"})
df["prompt"] = df.apply(
    lambda row: f"Créer une description de post pour un produit de la marque {row['Brand Name']}.\n"
                f"Avis clients : {row['Review']}\n"
                f"Nombre de likes précédents : {row['likesCount']}",
    axis=1
)

# 2. Initialize model with quantization
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-2-7b-chat-hf",
    quantization_config=quant_config,
    device_map="auto"
)

# 3. Add LoRA adapters
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
model = get_peft_model(model, peft_config)

# 4. Initialize tokenizer
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf")
tokenizer.pad_token = tokenizer.eos_token

# 5. Convert to Dataset and split
dataset = Dataset.from_pandas(df[["prompt", "response"]])
split_dataset = dataset.train_test_split(test_size=0.2)

# 6. Tokenization function
def tokenize_function(examples):
    texts = [f"### Instruction:\n{p}\n\n### Response:\n{r}"
             for p, r in zip(examples['prompt'], examples['response'])]

    tokenized = tokenizer(
        texts,
        truncation=True,
        padding="max_length",
        max_length=512,
        return_tensors="pt"
    )
    tokenized["labels"] = tokenized["input_ids"].clone()
    return tokenized

tokenized_datasets = split_dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=split_dataset["train"].column_names
)

# 7. Training setup
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=2,
    num_train_epochs=1,
    logging_steps=10,
    save_steps=100,
    fp16=True,
    eval_strategy="epoch",  # Updated from evaluation_strategy
    save_total_limit=2,
    gradient_accumulation_steps=2
)

# 8. Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
)

# 9. Train
trainer.train()
# Out:
# ...
# Map:   0%|          | 0/2052 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# ...

# %%
# Save the full model (base weights + adapters)
model.save_pretrained("./saved_model")
tokenizer.save_pretrained("./saved_model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-465d4a60facb> in <cell line: 0>()
#       1 # Save the full model (base weights + adapters)
# ----> 2 model.save_pretrained("./saved_model")
#       3 tokenizer.save_pretrained("./saved_model")
#
# NameError: name 'model' is not defined

# %%
def generate_response(prompt):
    input_text = f"### Instruction:\n{prompt}\n\n### Response:\n"
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=200)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Test
print(generate_response("Crée une description pour un produit Nike."))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ac97b2777c4f> in <cell line: 0>()
#       6
#       7 # Test
# ----> 8 print(generate_response("Crée une description pour un produit Nike."))
#
# <ipython-input-2-ac97b2777c4f> in generate_response(prompt)
#       1 def generate_response(prompt):
#       2     input_text = f"### Instruction:\n{prompt}\n\n### Response:\n"
# ----> 3     inputs = tokenizer(input_text, return_tensors="pt").to("cuda")
#       4     outputs = model.generate(**inputs, max_new_tokens=200)
#       5     return tokenizer.decode(outputs[0], skip_special_tokens=True)
#
# NameError: name 'tokenizer' is not defined
